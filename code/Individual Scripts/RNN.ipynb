# %% [markdown]
# #### RNN Classification (Keras Tensorflow)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# coding= UTF-8
import os
import numpy as np
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam

# Load data
X = np.load("/content/drive/MyDrive/Speaker_Fluency/data/feat.npy")
y = np.load('/content/drive/MyDrive/Speaker_Fluency/data/label.npy').ravel()

# Fix random seed number
np.random.seed(7)

number_of_features = len(X[1])
number_of_classes = 3

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 230)


# Reshape data for LSTM (Samples, Timesteps, Features)
X_train = np.expand_dims(X_train, axis=2) #(280,193,1)
X_test = np.expand_dims(X_test, axis=2)

y_train = keras.utils.to_categorical(y_train - 1, num_classes= number_of_classes) # Converts a class vector (integers) to binary class matrix
y_test = keras.utils.to_categorical(y_test - 1, num_classes= number_of_classes)

# Build RNN Neural Network
print('Build LSTM RNN model ...')
model = Sequential()
model.add(LSTM(256, return_sequences=True, input_shape=X_train.shape[1:]))
model.add(LSTM(32, return_sequences=False))
model.add(Dense(number_of_classes, activation='softmax'))

print("Compiling ...")
model.compile(loss='categorical_crossentropy', # for multiple classes
              optimizer='rmsprop',
              metrics=['accuracy'])

print(model.summary())

print("Training ...")
model.fit(X_train, y_train, batch_size=64, epochs=60)

print("\nValidating ...")
score, accuracy = model.evaluate(X_test, y_test, batch_size=32, verbose=1)
print("Loss:  ", score)
print("Accuracy:  ", accuracy)
# Out:
# Build LSTM RNN model ...
# Compiling ...
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 23, 256)           264192
#
#  lstm_3 (LSTM)               (None, 32)                36992
#
#  dense_1 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 301283 (1.15 MB)
# Trainable params: 301283 (1.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training ...
# Epoch 1/60
# 16/16 [==============================] - 7s 182ms/step - loss: 0.9923 - accuracy: 0.5010
# Epoch 2/60
# 16/16 [==============================] - 2s 112ms/step - loss: 0.8294 - accuracy: 0.5984
# Epoch 3/60
# 16/16 [==============================] - 2s 109ms/step - loss: 0.7424 - accuracy: 0.6627
# Epoch 4/60
# 16/16 [==============================] - 2s 112ms/step - loss: 0.6732 - accuracy: 0.6827
# Epoch 5/60
# 16/16 [==============================] - 2s 115ms/step - loss: 0.6147 - accuracy: 0.7048
# Epoch 6/60
# 16/16 [==============================] - 2s 115ms/step - loss: 0.5873 - accuracy: 0.7199
# Epoch 7/60
# 16/16 [==============================] - 2s 146ms/step - loss: 0.5555 - accuracy: 0.7410
# Epoch 8/60
# 16/16 [==============================] - 3s 181ms/step - loss: 0.5411 - accuracy: 0.7631
# Epoch 9/60
# 16/16 [==============================] - 2s 113ms/step - loss: 0.5200 - accuracy: 0.7610
# Epoch 10/60
# 16/16 [==============================] - 2s 113ms/step - loss: 0.4885 - accuracy: 0.7651
# Epoch 11/60
# 16/16 [==============================] - 2s 113ms/step - loss: 0.4807 - accuracy: 0.7841
# Epoch 12/60
# 16/16 [==============================] - 2s 115ms/step - loss: 0.4534 - accuracy: 0.7882
# Epoch 13/60
# 16/16 [==============================] - 2s 116ms/step - loss: 0.4415 - accuracy: 0.7922
# Epoch 14/60
# 16/16 [==============================] - 2s 143ms/step - loss: 0.4428 - accuracy: 0.7871
# Epoch 15/60
# 16/16 [==============================] - 3s 186ms/step - loss: 0.4405 - accuracy: 0.8002
# Epoch 16/60
# 16/16 [==============================] - 3s 156ms/step - loss: 0.4119 - accuracy: 0.8092
# Epoch 17/60
# 16/16 [==============================] - 2s 114ms/step - loss: 0.4112 - accuracy: 0.8102
# Epoch 18/60
# 16/16 [==============================] - 2s 116ms/step - loss: 0.4002 - accuracy: 0.8082
# Epoch 19/60
# 16/16 [==============================] - 2s 113ms/step - loss: 0.3693 - accuracy: 0.8193
# Epoch 20/60
# 16/16 [==============================] - 2s 116ms/step - loss: 0.4055 - accuracy: 0.8133
# Epoch 21/60
# 16/16 [==============================] - 3s 174ms/step - loss: 0.3494 - accuracy: 0.8414
# Epoch 22/60
# 16/16 [==============================] - 3s 159ms/step - loss: 0.3582 - accuracy: 0.8323
# Epoch 23/60
# 16/16 [==============================] - 2s 112ms/step - loss: 0.3681 - accuracy: 0.8213
# Epoch 24/60
# 16/16 [==============================] - 2s 114ms/step - loss: 0.3274 - accuracy: 0.8424
# Epoch 25/60
# 16/16 [==============================] - 2s 114ms/step - loss: 0.3390 - accuracy: 0.8283
# Epoch 26/60
# 16/16 [==============================] - 2s 113ms/step - loss: 0.3504 - accuracy: 0.8343
# Epoch 27/60
# 16/16 [==============================] - 2s 114ms/step - loss: 0.2976 - accuracy: 0.8614
# Epoch 28/60
# 16/16 [==============================] - 3s 166ms/step - loss: 0.3322 - accuracy: 0.8444
# Epoch 29/60
# 16/16 [==============================] - 3s 166ms/step - loss: 0.3097 - accuracy: 0.8604
# Epoch 30/60
# 16/16 [==============================] - 2s 137ms/step - loss: 0.2882 - accuracy: 0.8745
# Epoch 31/60
# 16/16 [==============================] - 2s 114ms/step - loss: 0.2660 - accuracy: 0.8715
# Epoch 32/60
# 16/16 [==============================] - 2s 114ms/step - loss: 0.2752 - accuracy: 0.8685
# Epoch 33/60
# 16/16 [==============================] - 2s 114ms/step - loss: 0.2905 - accuracy: 0.8624
# Epoch 34/60
# 16/16 [==============================] - 2s 122ms/step - loss: 0.2476 - accuracy: 0.8765
# Epoch 35/60
# 16/16 [==============================] - 3s 180ms/step - loss: 0.2546 - accuracy: 0.8916
# Epoch 36/60
# 16/16 [==============================] - 2s 143ms/step - loss: 0.2406 - accuracy: 0.8795
# Epoch 37/60
# 16/16 [==============================] - 2s 113ms/step - loss: 0.2223 - accuracy: 0.8916
# Epoch 38/60
# 16/16 [==============================] - 2s 113ms/step - loss: 0.2450 - accuracy: 0.8765
# Epoch 39/60
# 16/16 [==============================] - 2s 114ms/step - loss: 0.2167 - accuracy: 0.9006
# Epoch 40/60
# 16/16 [==============================] - 2s 116ms/step - loss: 0.2414 - accuracy: 0.8886
# Epoch 41/60
# 16/16 [==============================] - 2s 117ms/step - loss: 0.1973 - accuracy: 0.9147
# Epoch 42/60
# 16/16 [==============================] - 3s 179ms/step - loss: 0.2215 - accuracy: 0.9096
# Epoch 43/60
# 16/16 [==============================] - 2s 146ms/step - loss: 0.1836 - accuracy: 0.9157
# Epoch 44/60
# 16/16 [==============================] - 2s 114ms/step - loss: 0.2019 - accuracy: 0.9086
# Epoch 45/60
# 16/16 [==============================] - 2s 114ms/step - loss: 0.1811 - accuracy: 0.9197
# Epoch 46/60
# 16/16 [==============================] - 2s 113ms/step - loss: 0.2249 - accuracy: 0.9006
# Epoch 47/60
# 16/16 [==============================] - 2s 118ms/step - loss: 0.1653 - accuracy: 0.9307
# Epoch 48/60
# 16/16 [==============================] - 2s 120ms/step - loss: 0.2063 - accuracy: 0.9076
# Epoch 49/60
# 16/16 [==============================] - 3s 180ms/step - loss: 0.1862 - accuracy: 0.9096
# Epoch 50/60
# 16/16 [==============================] - 2s 143ms/step - loss: 0.1649 - accuracy: 0.9357
# Epoch 51/60
# 16/16 [==============================] - 2s 113ms/step - loss: 0.1726 - accuracy: 0.9267
# Epoch 52/60
# 16/16 [==============================] - 2s 112ms/step - loss: 0.1610 - accuracy: 0.9227
# Epoch 53/60
# 16/16 [==============================] - 2s 113ms/step - loss: 0.1473 - accuracy: 0.9428
# Epoch 54/60
# 16/16 [==============================] - 2s 113ms/step - loss: 0.1785 - accuracy: 0.9217
# Epoch 55/60
# 16/16 [==============================] - 2s 113ms/step - loss: 0.1489 - accuracy: 0.9388
# Epoch 56/60
# 16/16 [==============================] - 3s 180ms/step - loss: 0.1501 - accuracy: 0.9388
# Epoch 57/60
# 16/16 [==============================] - 2s 149ms/step - loss: 0.1388 - accuracy: 0.9408
# Epoch 58/60
# 16/16 [==============================] - 2s 112ms/step - loss: 0.1380 - accuracy: 0.9347
# Epoch 59/60
# 16/16 [==============================] - 2s 112ms/step - loss: 0.1297 - accuracy: 0.9418
# Epoch 60/60
# 16/16 [==============================] - 2s 112ms/step - loss: 0.1432 - accuracy: 0.9488
#
# Validating ...
# 14/14 [==============================] - 2s 48ms/step - loss: 0.3843 - accuracy: 0.8621
# Loss:   0.38434475660324097
# Accuracy:   0.8621495366096497
